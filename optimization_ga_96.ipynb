# %%
from joblib import Parallel, delayed
import numpy as np
import os
from evoman.environment import Environment
from demo_controller import player_controller

headless = True
if headless:
    os.environ["SDL_VIDEODRIVER"] = "dummy"

experiment_name = 'dummy_demo'
solutions_dir = 'solutions'

if not os.path.exists(experiment_name):
    os.makedirs(experiment_name)

if not os.path.exists(solutions_dir):
    os.makedirs(solutions_dir)

crossover_parameter = 0.5
mutation_probability = 0.2
size_of_pop = 100
generations = 30
n_hidden = 10
dom_l = -1
dom_u = 1
n_jobs = -1  # Use all available CPU cores
runs = 10

# Get fitness for individual
def simulate(individual, enemy):
    env = Environment(experiment_name=experiment_name,
                      enemies=[enemy],
                      playermode="ai",
                      player_controller=player_controller(n_hidden),
                      enemymode="static",
                      level=2,
                      speed="fastest",
                      visuals=False)
    fitness, player_energy, enemy_energy, time = env.play(pcont=individual)
    fitness_value = 0.9 * (100 - enemy_energy) + 0.1 * player_energy - np.log(time)
    return fitness_value

# Evaluate population in parallel
def evaluate(population, enemy):
    return np.array(Parallel(n_jobs=n_jobs)(delayed(simulate)(individual, enemy) for individual in population))

# Select the fittest
def tourn_selection(population, fitness):
    index_1, index_2 = np.random.choice(np.arange(len(population)), size=2, replace=False)
    return population[index_1] if fitness[index_1] > fitness[index_2] else population[index_2]

# Uniform Crossover
def uniform_crossover(parent_1, parent_2, crossover_parameter):
    crossover_boolean = np.random.rand(len(parent_1)) < crossover_parameter
    offspring = np.where(crossover_boolean, parent_1, parent_2)
    return offspring

# Mutation
def mutate(individual, mutation_probability):
    mutation_positions = np.random.rand(len(individual)) < mutation_probability
    mutation_change = np.random.normal(0, 1, size=len(individual))
    individual[mutation_positions] += mutation_change[mutation_positions]
    individual = np.clip(individual, dom_l, dom_u)
    return individual

# Initialize population
def initialize_population(size, number_of_variables):
    return np.random.uniform(dom_l, dom_u, (size, number_of_variables))

# Save final results (only for best params)
def save_final_results(fittest_individual, best_fitness, enemy, best_params):
    with open(f"{experiment_name}/results.txt", "w") as results_file:
        results_file.write(f"Best Parameters: Mutation {best_params['mutation_probability']}, Crossover {best_params['crossover_parameter']}\n")
        results_file.write(f"Best Fitness: {best_fitness}\n")
    
    np.savetxt(f"{experiment_name}/best.txt", fittest_individual)
    with open(f"{experiment_name}/gen.txt", "w") as gen_file:
        gen_file.write("Final best individual saved after tuning.\n")

# Evolution
def evolution(enemy, size_of_pop, generations, mutation_probability, crossover_parameter):
    env = Environment(experiment_name=experiment_name, enemies=[enemy], playermode="ai", player_controller=player_controller(n_hidden), enemymode="static", level=2, speed="fastest", visuals=False)
    amount_of_vars = (env.get_num_sensors() + 1) * n_hidden + (n_hidden + 1) * 5
    population = initialize_population(size_of_pop, amount_of_vars)
    fitness = evaluate(population, enemy)

    best_fitness_per_generation = []

    for generation in range(generations):
        new_pop = []

        for i in range(size_of_pop // 2):
            parent_1 = tourn_selection(population, fitness)
            parent_2 = tourn_selection(population, fitness)

            child1 = mutate(uniform_crossover(parent_1, parent_2, crossover_parameter), mutation_probability)
            child2 = mutate(uniform_crossover(parent_2, parent_1, crossover_parameter), mutation_probability)

            new_pop.extend([child1, child2])

        population = np.array(new_pop)
        fitness = evaluate(population, enemy)

        fittest_index = np.argmax(fitness)
        fittest_individual = population[fittest_index]
        best_fitness_per_generation.append(np.max(fitness))

    return fittest_individual, np.max(fitness), best_fitness_per_generation

# Broad search
def grid_search(enemy, size_of_pop, generations):
    best_fitness = -np.inf
    best_params = {'mutation_probability': None, 'crossover_parameter': None}

    mutation_range = np.linspace(0.01, 0.1, 5) 
    crossover_range = np.linspace(0.3, 0.7, 5) 

    for mutation_probability in mutation_range:
        for crossover_parameter in crossover_range:
            print(f"Testing mutation: {mutation_probability}, crossover: {crossover_parameter}")
            fittestgrid, max_fitness, bestfitgengrid = evolution(enemy, size_of_pop, generations, mutation_probability, crossover_parameter)

            if max_fitness > best_fitness:
                best_fitness = max_fitness
                best_params = {'mutation_probability': mutation_probability, 'crossover_parameter': crossover_parameter}

    return best_params, best_fitness

# Fine search
def fine_tune_search(enemy, size_of_pop, generations, best_params):
    best_fitness = -np.inf
    fine_mutation_range = np.linspace(best_params['mutation_probability'] - 0.005, best_params['mutation_probability'] + 0.005, 5)
    fine_crossover_range = np.linspace(best_params['crossover_parameter'] - 0.05, best_params['crossover_parameter'] + 0.05, 5)

    for mutation_probability in fine_mutation_range:
        for crossover_parameter in fine_crossover_range:
            print(f"Fine-tuning mutation: {mutation_probability}, crossover: {crossover_parameter}")
            fittest_individual, max_fitness, bestfitgentune = evolution(enemy, size_of_pop, generations, mutation_probability, crossover_parameter)

            if max_fitness > best_fitness:
                best_fitness = max_fitness
                best_individual = fittest_individual
                best_params = {'mutation_probability': mutation_probability, 'crossover_parameter': crossover_parameter}

    return best_params, best_fitness, best_individual

# Main function
def run():
    all_best_individuals = []
    run_results = []

    for enemy in [3]:
        print(f'\nResults for enemy {enemy}\n')

        for run in range(runs):
            print(f"Run {run+1}/{runs}")

            print("Broad parameter search has started")
            best_params, bestfitgridsearch = grid_search(enemy, size_of_pop, generations)

            print("Fine-tuning search has started")
            best_params, best_fitness, best_individual = fine_tune_search(enemy, size_of_pop, generations, best_params)

            print(f"Run {run+1} - Best parameters after fine-tuning: {best_params}, with fitness: {best_fitness}")
            run_results.append((best_params, best_fitness, best_individual))

    # Calculate mean
    param_fitness_means = {}

    for params, fitness, individual in run_results:
        param_key = (params['mutation_probability'], params['crossover_parameter'])

        if param_key in param_fitness_means:
            param_fitness_means[param_key].append(fitness)
        else:
            param_fitness_means[param_key] = [fitness]

    # Get parameters
    best_mean_params = max(param_fitness_means.items(), key=lambda x: np.mean(x[1]))[0]
    best_mean_fitness = np.mean(param_fitness_means[best_mean_params])

    # Find best individual
    for params, fitness, individual in run_results:
        if (params['mutation_probability'], params['crossover_parameter']) == best_mean_params:
            best_individual = individual
            break

    print(f"\nBest parameters based on mean fitness: Mutation {best_mean_params[0]}, Crossover {best_mean_params[1]} with mean fitness: {best_mean_fitness}")
    
    # Save the final results
    save_final_results(best_individual, best_mean_fitness, enemy, {'mutation_probability': best_mean_params[0], 'crossover_parameter': best_mean_params[1]})

run()
# Out:
# pygame 2.6.0 (SDL 2.28.4, Python 3.12.4)
# Hello from the pygame community. https://www.pygame.org/contribute.html
#
# Results for enemy 3
#
# Run 1/10
# Broad parameter search has started
# Testing mutation: 0.01, crossover: 0.3
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.01, crossover: 0.39999999999999997
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.01, crossover: 0.5
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.01, crossover: 0.6
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.01, crossover: 0.7
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0325, crossover: 0.3
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0325, crossover: 0.39999999999999997
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0325, crossover: 0.5
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0325, crossover: 0.6
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0325, crossover: 0.7
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.05500000000000001, crossover: 0.3
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.05500000000000001, crossover: 0.39999999999999997
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.05500000000000001, crossover: 0.5
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.05500000000000001, crossover: 0.6
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.05500000000000001, crossover: 0.7
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0775, crossover: 0.3
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0775, crossover: 0.39999999999999997
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0775, crossover: 0.5
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0775, crossover: 0.6
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0775, crossover: 0.7
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.1, crossover: 0.3
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.1, crossover: 0.39999999999999997
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.1, crossover: 0.5
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.1, crossover: 0.6
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.1, crossover: 0.7
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning search has started
# Fine-tuning mutation: 0.0275, crossover: 0.5499999999999999
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0275, crossover: 0.575
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0275, crossover: 0.6
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0275, crossover: 0.625
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0275, crossover: 0.65
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.03, crossover: 0.5499999999999999
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.03, crossover: 0.575
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.03, crossover: 0.6
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.03, crossover: 0.625
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.03, crossover: 0.65
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0325, crossover: 0.5499999999999999
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0325, crossover: 0.575
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0325, crossover: 0.6
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0325, crossover: 0.625
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0325, crossover: 0.65
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.034999999999999996, crossover: 0.5499999999999999
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.034999999999999996, crossover: 0.575
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.034999999999999996, crossover: 0.6
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.034999999999999996, crossover: 0.625
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.034999999999999996, crossover: 0.65
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0375, crossover: 0.5499999999999999
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0375, crossover: 0.575
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0375, crossover: 0.6
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0375, crossover: 0.625
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0375, crossover: 0.65
#
# MESSAGE: Pygame initialized for simulation.
# Run 1 - Best parameters after fine-tuning: {'mutation_probability': 0.0275, 'crossover_parameter': 0.575}, with fitness: 90.92926227199752
# Run 2/10
# Broad parameter search has started
# Testing mutation: 0.01, crossover: 0.3
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.01, crossover: 0.39999999999999997
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.01, crossover: 0.5
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.01, crossover: 0.6
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.01, crossover: 0.7
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0325, crossover: 0.3
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0325, crossover: 0.39999999999999997
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0325, crossover: 0.5
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0325, crossover: 0.6
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0325, crossover: 0.7
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.05500000000000001, crossover: 0.3
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.05500000000000001, crossover: 0.39999999999999997
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.05500000000000001, crossover: 0.5
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.05500000000000001, crossover: 0.6
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.05500000000000001, crossover: 0.7
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0775, crossover: 0.3
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0775, crossover: 0.39999999999999997
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0775, crossover: 0.5
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0775, crossover: 0.6
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0775, crossover: 0.7
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.1, crossover: 0.3
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.1, crossover: 0.39999999999999997
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.1, crossover: 0.5
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.1, crossover: 0.6
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.1, crossover: 0.7
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning search has started
# Fine-tuning mutation: 0.0275, crossover: 0.5499999999999999
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0275, crossover: 0.575
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0275, crossover: 0.6
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0275, crossover: 0.625
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0275, crossover: 0.65
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.03, crossover: 0.5499999999999999
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.03, crossover: 0.575
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.03, crossover: 0.6
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.03, crossover: 0.625
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.03, crossover: 0.65
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0325, crossover: 0.5499999999999999
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0325, crossover: 0.575
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0325, crossover: 0.6
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0325, crossover: 0.625
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0325, crossover: 0.65
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.034999999999999996, crossover: 0.5499999999999999
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.034999999999999996, crossover: 0.575
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.034999999999999996, crossover: 0.6
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.034999999999999996, crossover: 0.625
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.034999999999999996, crossover: 0.65
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0375, crossover: 0.5499999999999999
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0375, crossover: 0.575
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0375, crossover: 0.6
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0375, crossover: 0.625
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0375, crossover: 0.65
#
# MESSAGE: Pygame initialized for simulation.
# Run 2 - Best parameters after fine-tuning: {'mutation_probability': 0.0275, 'crossover_parameter': 0.65}, with fitness: 91.55974528872258
# Run 3/10
# Broad parameter search has started
# Testing mutation: 0.01, crossover: 0.3
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.01, crossover: 0.39999999999999997
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.01, crossover: 0.5
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.01, crossover: 0.6
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.01, crossover: 0.7
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0325, crossover: 0.3
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0325, crossover: 0.39999999999999997
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0325, crossover: 0.5
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0325, crossover: 0.6
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0325, crossover: 0.7
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.05500000000000001, crossover: 0.3
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.05500000000000001, crossover: 0.39999999999999997
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.05500000000000001, crossover: 0.5
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.05500000000000001, crossover: 0.6
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.05500000000000001, crossover: 0.7
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0775, crossover: 0.3
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0775, crossover: 0.39999999999999997
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0775, crossover: 0.5
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0775, crossover: 0.6
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0775, crossover: 0.7
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.1, crossover: 0.3
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.1, crossover: 0.39999999999999997
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.1, crossover: 0.5
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.1, crossover: 0.6
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.1, crossover: 0.7
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning search has started
# Fine-tuning mutation: 0.0725, crossover: 0.25
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0725, crossover: 0.275
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0725, crossover: 0.3
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0725, crossover: 0.32499999999999996
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0725, crossover: 0.35
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.075, crossover: 0.25
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.075, crossover: 0.275
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.075, crossover: 0.3
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.075, crossover: 0.32499999999999996
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.075, crossover: 0.35
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0775, crossover: 0.25
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0775, crossover: 0.275
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0775, crossover: 0.3
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0775, crossover: 0.32499999999999996
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0775, crossover: 0.35
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.08, crossover: 0.25
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.08, crossover: 0.275
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.08, crossover: 0.3
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.08, crossover: 0.32499999999999996
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.08, crossover: 0.35
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0825, crossover: 0.25
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0825, crossover: 0.275
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0825, crossover: 0.3
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0825, crossover: 0.32499999999999996
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0825, crossover: 0.35
#
# MESSAGE: Pygame initialized for simulation.
# Run 3 - Best parameters after fine-tuning: {'mutation_probability': 0.08, 'crossover_parameter': 0.3}, with fitness: 90.01585110906252
# Run 4/10
# Broad parameter search has started
# Testing mutation: 0.01, crossover: 0.3
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.01, crossover: 0.39999999999999997
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.01, crossover: 0.5
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.01, crossover: 0.6
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.01, crossover: 0.7
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0325, crossover: 0.3
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0325, crossover: 0.39999999999999997
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0325, crossover: 0.5
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0325, crossover: 0.6
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0325, crossover: 0.7
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.05500000000000001, crossover: 0.3
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.05500000000000001, crossover: 0.39999999999999997
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.05500000000000001, crossover: 0.5
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.05500000000000001, crossover: 0.6
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.05500000000000001, crossover: 0.7
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0775, crossover: 0.3
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0775, crossover: 0.39999999999999997
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0775, crossover: 0.5
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0775, crossover: 0.6
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0775, crossover: 0.7
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.1, crossover: 0.3
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.1, crossover: 0.39999999999999997
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.1, crossover: 0.5
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.1, crossover: 0.6
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.1, crossover: 0.7
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning search has started
# Fine-tuning mutation: 0.005, crossover: 0.25
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.005, crossover: 0.275
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.005, crossover: 0.3
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.005, crossover: 0.32499999999999996
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.005, crossover: 0.35
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0075, crossover: 0.25
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0075, crossover: 0.275
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0075, crossover: 0.3
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0075, crossover: 0.32499999999999996
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0075, crossover: 0.35
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.009999999999999998, crossover: 0.25
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.009999999999999998, crossover: 0.275
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.009999999999999998, crossover: 0.3
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.009999999999999998, crossover: 0.32499999999999996
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.009999999999999998, crossover: 0.35
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.012499999999999999, crossover: 0.25
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.012499999999999999, crossover: 0.275
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.012499999999999999, crossover: 0.3
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.012499999999999999, crossover: 0.32499999999999996
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.012499999999999999, crossover: 0.35
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.015, crossover: 0.25
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.015, crossover: 0.275
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.015, crossover: 0.3
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.015, crossover: 0.32499999999999996
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.015, crossover: 0.35
#
# MESSAGE: Pygame initialized for simulation.
# Run 4 - Best parameters after fine-tuning: {'mutation_probability': 0.015, 'crossover_parameter': 0.35}, with fitness: 90.84935744741227
# Run 5/10
# Broad parameter search has started
# Testing mutation: 0.01, crossover: 0.3
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.01, crossover: 0.39999999999999997
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.01, crossover: 0.5
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.01, crossover: 0.6
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.01, crossover: 0.7
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0325, crossover: 0.3
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0325, crossover: 0.39999999999999997
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0325, crossover: 0.5
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0325, crossover: 0.6
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0325, crossover: 0.7
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.05500000000000001, crossover: 0.3
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.05500000000000001, crossover: 0.39999999999999997
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.05500000000000001, crossover: 0.5
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.05500000000000001, crossover: 0.6
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.05500000000000001, crossover: 0.7
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0775, crossover: 0.3
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0775, crossover: 0.39999999999999997
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0775, crossover: 0.5
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0775, crossover: 0.6
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0775, crossover: 0.7
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.1, crossover: 0.3
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.1, crossover: 0.39999999999999997
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.1, crossover: 0.5
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.1, crossover: 0.6
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.1, crossover: 0.7
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning search has started
# Fine-tuning mutation: 0.0725, crossover: 0.6499999999999999
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0725, crossover: 0.6749999999999999
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0725, crossover: 0.7
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0725, crossover: 0.725
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0725, crossover: 0.75
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.075, crossover: 0.6499999999999999
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.075, crossover: 0.6749999999999999
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.075, crossover: 0.7
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.075, crossover: 0.725
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.075, crossover: 0.75
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0775, crossover: 0.6499999999999999
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0775, crossover: 0.6749999999999999
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0775, crossover: 0.7
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0775, crossover: 0.725
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0775, crossover: 0.75
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.08, crossover: 0.6499999999999999
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.08, crossover: 0.6749999999999999
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.08, crossover: 0.7
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.08, crossover: 0.725
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.08, crossover: 0.75
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0825, crossover: 0.6499999999999999
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0825, crossover: 0.6749999999999999
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0825, crossover: 0.7
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0825, crossover: 0.725
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0825, crossover: 0.75
#
# MESSAGE: Pygame initialized for simulation.
# Run 5 - Best parameters after fine-tuning: {'mutation_probability': 0.0725, 'crossover_parameter': 0.725}, with fitness: 91.15974528872259
# Run 6/10
# Broad parameter search has started
# Testing mutation: 0.01, crossover: 0.3
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.01, crossover: 0.39999999999999997
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.01, crossover: 0.5
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.01, crossover: 0.6
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.01, crossover: 0.7
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0325, crossover: 0.3
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0325, crossover: 0.39999999999999997
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0325, crossover: 0.5
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0325, crossover: 0.6
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0325, crossover: 0.7
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.05500000000000001, crossover: 0.3
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.05500000000000001, crossover: 0.39999999999999997
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.05500000000000001, crossover: 0.5
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.05500000000000001, crossover: 0.6
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.05500000000000001, crossover: 0.7
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0775, crossover: 0.3
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0775, crossover: 0.39999999999999997
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0775, crossover: 0.5
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0775, crossover: 0.6
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0775, crossover: 0.7
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.1, crossover: 0.3
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.1, crossover: 0.39999999999999997
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.1, crossover: 0.5
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.1, crossover: 0.6
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.1, crossover: 0.7
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning search has started
# Fine-tuning mutation: 0.0725, crossover: 0.25
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0725, crossover: 0.275
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0725, crossover: 0.3
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0725, crossover: 0.32499999999999996
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0725, crossover: 0.35
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.075, crossover: 0.25
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.075, crossover: 0.275
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.075, crossover: 0.3
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.075, crossover: 0.32499999999999996
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.075, crossover: 0.35
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0775, crossover: 0.25
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0775, crossover: 0.275
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0775, crossover: 0.3
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0775, crossover: 0.32499999999999996
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0775, crossover: 0.35
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.08, crossover: 0.25
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.08, crossover: 0.275
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.08, crossover: 0.3
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.08, crossover: 0.32499999999999996
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.08, crossover: 0.35
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0825, crossover: 0.25
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0825, crossover: 0.275
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0825, crossover: 0.3
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0825, crossover: 0.32499999999999996
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0825, crossover: 0.35
#
# MESSAGE: Pygame initialized for simulation.
# Run 6 - Best parameters after fine-tuning: {'mutation_probability': 0.0825, 'crossover_parameter': 0.3}, with fitness: 90.22364909070207
# Run 7/10
# Broad parameter search has started
# Testing mutation: 0.01, crossover: 0.3
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.01, crossover: 0.39999999999999997
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.01, crossover: 0.5
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.01, crossover: 0.6
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.01, crossover: 0.7
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0325, crossover: 0.3
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0325, crossover: 0.39999999999999997
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0325, crossover: 0.5
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0325, crossover: 0.6
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0325, crossover: 0.7
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.05500000000000001, crossover: 0.3
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.05500000000000001, crossover: 0.39999999999999997
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.05500000000000001, crossover: 0.5
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.05500000000000001, crossover: 0.6
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.05500000000000001, crossover: 0.7
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0775, crossover: 0.3
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0775, crossover: 0.39999999999999997
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0775, crossover: 0.5
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0775, crossover: 0.6
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0775, crossover: 0.7
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.1, crossover: 0.3
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.1, crossover: 0.39999999999999997
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.1, crossover: 0.5
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.1, crossover: 0.6
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.1, crossover: 0.7
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning search has started
# Fine-tuning mutation: 0.0275, crossover: 0.45
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0275, crossover: 0.47500000000000003
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0275, crossover: 0.5
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0275, crossover: 0.525
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0275, crossover: 0.55
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.03, crossover: 0.45
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.03, crossover: 0.47500000000000003
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.03, crossover: 0.5
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.03, crossover: 0.525
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.03, crossover: 0.55
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0325, crossover: 0.45
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0325, crossover: 0.47500000000000003
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0325, crossover: 0.5
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0325, crossover: 0.525
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0325, crossover: 0.55
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.034999999999999996, crossover: 0.45
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.034999999999999996, crossover: 0.47500000000000003
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.034999999999999996, crossover: 0.5
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.034999999999999996, crossover: 0.525
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.034999999999999996, crossover: 0.55
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0375, crossover: 0.45
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0375, crossover: 0.47500000000000003
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0375, crossover: 0.5
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0375, crossover: 0.525
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0375, crossover: 0.55
#
# MESSAGE: Pygame initialized for simulation.
# Run 7 - Best parameters after fine-tuning: {'mutation_probability': 0.0275, 'crossover_parameter': 0.525}, with fitness: 89.92465396891131
# Run 8/10
# Broad parameter search has started
# Testing mutation: 0.01, crossover: 0.3
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.01, crossover: 0.39999999999999997
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.01, crossover: 0.5
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.01, crossover: 0.6
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.01, crossover: 0.7
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0325, crossover: 0.3
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0325, crossover: 0.39999999999999997
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0325, crossover: 0.5
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0325, crossover: 0.6
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0325, crossover: 0.7
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.05500000000000001, crossover: 0.3
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.05500000000000001, crossover: 0.39999999999999997
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.05500000000000001, crossover: 0.5
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.05500000000000001, crossover: 0.6
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.05500000000000001, crossover: 0.7
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0775, crossover: 0.3
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0775, crossover: 0.39999999999999997
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0775, crossover: 0.5
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0775, crossover: 0.6
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0775, crossover: 0.7
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.1, crossover: 0.3
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.1, crossover: 0.39999999999999997
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.1, crossover: 0.5
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.1, crossover: 0.6
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.1, crossover: 0.7
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning search has started
# Fine-tuning mutation: 0.0725, crossover: 0.45
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0725, crossover: 0.47500000000000003
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0725, crossover: 0.5
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0725, crossover: 0.525
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0725, crossover: 0.55
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.075, crossover: 0.45
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.075, crossover: 0.47500000000000003
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.075, crossover: 0.5
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.075, crossover: 0.525
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.075, crossover: 0.55
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0775, crossover: 0.45
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0775, crossover: 0.47500000000000003
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0775, crossover: 0.5
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0775, crossover: 0.525
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0775, crossover: 0.55
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.08, crossover: 0.45
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.08, crossover: 0.47500000000000003
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.08, crossover: 0.5
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.08, crossover: 0.525
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.08, crossover: 0.55
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0825, crossover: 0.45
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0825, crossover: 0.47500000000000003
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0825, crossover: 0.5
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0825, crossover: 0.525
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0825, crossover: 0.55
#
# MESSAGE: Pygame initialized for simulation.
# Run 8 - Best parameters after fine-tuning: {'mutation_probability': 0.075, 'crossover_parameter': 0.55}, with fitness: 89.75736716631762
# Run 9/10
# Broad parameter search has started
# Testing mutation: 0.01, crossover: 0.3
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.01, crossover: 0.39999999999999997
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.01, crossover: 0.5
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.01, crossover: 0.6
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.01, crossover: 0.7
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0325, crossover: 0.3
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0325, crossover: 0.39999999999999997
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0325, crossover: 0.5
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0325, crossover: 0.6
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0325, crossover: 0.7
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.05500000000000001, crossover: 0.3
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.05500000000000001, crossover: 0.39999999999999997
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.05500000000000001, crossover: 0.5
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.05500000000000001, crossover: 0.6
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.05500000000000001, crossover: 0.7
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0775, crossover: 0.3
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0775, crossover: 0.39999999999999997
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0775, crossover: 0.5
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0775, crossover: 0.6
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0775, crossover: 0.7
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.1, crossover: 0.3
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.1, crossover: 0.39999999999999997
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.1, crossover: 0.5
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.1, crossover: 0.6
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.1, crossover: 0.7
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning search has started
# Fine-tuning mutation: 0.0275, crossover: 0.45
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0275, crossover: 0.47500000000000003
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0275, crossover: 0.5
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0275, crossover: 0.525
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0275, crossover: 0.55
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.03, crossover: 0.45
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.03, crossover: 0.47500000000000003
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.03, crossover: 0.5
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.03, crossover: 0.525
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.03, crossover: 0.55
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0325, crossover: 0.45
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0325, crossover: 0.47500000000000003
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0325, crossover: 0.5
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0325, crossover: 0.525
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0325, crossover: 0.55
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.034999999999999996, crossover: 0.45
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.034999999999999996, crossover: 0.47500000000000003
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.034999999999999996, crossover: 0.5
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.034999999999999996, crossover: 0.525
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.034999999999999996, crossover: 0.55
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0375, crossover: 0.45
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0375, crossover: 0.47500000000000003
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0375, crossover: 0.5
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0375, crossover: 0.525
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0375, crossover: 0.55
#
# MESSAGE: Pygame initialized for simulation.
# Run 9 - Best parameters after fine-tuning: {'mutation_probability': 0.034999999999999996, 'crossover_parameter': 0.47500000000000003}, with fitness: 91.45457939139342
# Run 10/10
# Broad parameter search has started
# Testing mutation: 0.01, crossover: 0.3
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.01, crossover: 0.39999999999999997
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.01, crossover: 0.5
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.01, crossover: 0.6
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.01, crossover: 0.7
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0325, crossover: 0.3
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0325, crossover: 0.39999999999999997
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0325, crossover: 0.5
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0325, crossover: 0.6
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0325, crossover: 0.7
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.05500000000000001, crossover: 0.3
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.05500000000000001, crossover: 0.39999999999999997
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.05500000000000001, crossover: 0.5
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.05500000000000001, crossover: 0.6
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.05500000000000001, crossover: 0.7
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0775, crossover: 0.3
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0775, crossover: 0.39999999999999997
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0775, crossover: 0.5
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0775, crossover: 0.6
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0775, crossover: 0.7
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.1, crossover: 0.3
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.1, crossover: 0.39999999999999997
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.1, crossover: 0.5
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.1, crossover: 0.6
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.1, crossover: 0.7
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning search has started
# Fine-tuning mutation: 0.0275, crossover: 0.25
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0275, crossover: 0.275
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0275, crossover: 0.3
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0275, crossover: 0.32499999999999996
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0275, crossover: 0.35
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.03, crossover: 0.25
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.03, crossover: 0.275
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.03, crossover: 0.3
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.03, crossover: 0.32499999999999996
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.03, crossover: 0.35
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0325, crossover: 0.25
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0325, crossover: 0.275
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0325, crossover: 0.3
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0325, crossover: 0.32499999999999996
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0325, crossover: 0.35
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.034999999999999996, crossover: 0.25
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.034999999999999996, crossover: 0.275
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.034999999999999996, crossover: 0.3
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.034999999999999996, crossover: 0.32499999999999996
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.034999999999999996, crossover: 0.35
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0375, crossover: 0.25
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0375, crossover: 0.275
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0375, crossover: 0.3
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0375, crossover: 0.32499999999999996
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0375, crossover: 0.35
#
# MESSAGE: Pygame initialized for simulation.
# Run 10 - Best parameters after fine-tuning: {'mutation_probability': 0.0275, 'crossover_parameter': 0.32499999999999996}, with fitness: 88.79342407327508
#
# Best parameters based on mean fitness: Mutation 0.0275, Crossover 0.65 with mean fitness: 91.55974528872258

# %%
from joblib import Parallel, delayed
import numpy as np
import os
from evoman.environment import Environment
from demo_controller import player_controller

headless = True
if headless:
    os.environ["SDL_VIDEODRIVER"] = "dummy"

experiment_name = 'dummy_demo1'
solutions_dir = 'solutions'

if not os.path.exists(experiment_name):
    os.makedirs(experiment_name)

if not os.path.exists(solutions_dir):
    os.makedirs(solutions_dir)

crossover_parameter = 0.5
mutation_probability = 0.2
size_of_pop = 100
generations = 30
n_hidden = 10
dom_l = -1
dom_u = 1
n_jobs = -1  # Use all available CPU cores
runs = 10

# Get fitness for individual
def simulate(individual, enemy):
    env = Environment(experiment_name=experiment_name,
                      enemies=[enemy],
                      playermode="ai",
                      player_controller=player_controller(n_hidden),
                      enemymode="static",
                      level=2,
                      speed="fastest",
                      visuals=False)
    fitness, player_energy, enemy_energy, time = env.play(pcont=individual)
    fitness_value = 0.1 * (100 - enemy_energy) + 0.9 * player_energy - np.log(time)
    return fitness_value

# Evaluate population in parallel
def evaluate(population, enemy):
    return np.array(Parallel(n_jobs=n_jobs)(delayed(simulate)(individual, enemy) for individual in population))

# Select the fittest
def tourn_selection(population, fitness):
    index_1, index_2 = np.random.choice(np.arange(len(population)), size=2, replace=False)
    return population[index_1] if fitness[index_1] > fitness[index_2] else population[index_2]

# Uniform Crossover
def uniform_crossover(parent_1, parent_2, crossover_parameter):
    crossover_boolean = np.random.rand(len(parent_1)) < crossover_parameter
    offspring = np.where(crossover_boolean, parent_1, parent_2)
    return offspring

# Mutation
def mutate(individual, mutation_probability):
    mutation_positions = np.random.rand(len(individual)) < mutation_probability
    mutation_change = np.random.normal(0, 1, size=len(individual))
    individual[mutation_positions] += mutation_change[mutation_positions]
    individual = np.clip(individual, dom_l, dom_u)
    return individual

# Initialize population
def initialize_population(size, number_of_variables):
    return np.random.uniform(dom_l, dom_u, (size, number_of_variables))

# Save final results (only for best params)
def save_final_results(fittest_individual, best_fitness, enemy, best_params):
    with open(f"{experiment_name}/results.txt", "w") as results_file:
        results_file.write(f"Best Parameters: Mutation {best_params['mutation_probability']}, Crossover {best_params['crossover_parameter']}\n")
        results_file.write(f"Best Fitness: {best_fitness}\n")
    
    np.savetxt(f"{experiment_name}/best.txt", fittest_individual)
    with open(f"{experiment_name}/gen.txt", "w") as gen_file:
        gen_file.write("Final best individual saved after tuning.\n")

# Evolution
def evolution(enemy, size_of_pop, generations, mutation_probability, crossover_parameter):
    env = Environment(experiment_name=experiment_name, enemies=[enemy], playermode="ai", player_controller=player_controller(n_hidden), enemymode="static", level=2, speed="fastest", visuals=False)
    amount_of_vars = (env.get_num_sensors() + 1) * n_hidden + (n_hidden + 1) * 5
    population = initialize_population(size_of_pop, amount_of_vars)
    fitness = evaluate(population, enemy)

    best_fitness_per_generation = []

    for generation in range(generations):
        new_pop = []

        for i in range(size_of_pop // 2):
            parent_1 = tourn_selection(population, fitness)
            parent_2 = tourn_selection(population, fitness)

            child1 = mutate(uniform_crossover(parent_1, parent_2, crossover_parameter), mutation_probability)
            child2 = mutate(uniform_crossover(parent_2, parent_1, crossover_parameter), mutation_probability)

            new_pop.extend([child1, child2])

        population = np.array(new_pop)
        fitness = evaluate(population, enemy)

        fittest_index = np.argmax(fitness)
        fittest_individual = population[fittest_index]
        best_fitness_per_generation.append(np.max(fitness))

    return fittest_individual, np.max(fitness), best_fitness_per_generation

# Broad search
def grid_search(enemy, size_of_pop, generations):
    best_fitness = -np.inf
    best_params = {'mutation_probability': None, 'crossover_parameter': None}

    mutation_range = np.linspace(0.01, 0.1, 5) 
    crossover_range = np.linspace(0.3, 0.7, 5) 

    for mutation_probability in mutation_range:
        for crossover_parameter in crossover_range:
            print(f"Testing mutation: {mutation_probability}, crossover: {crossover_parameter}")
            fittestgrid, max_fitness, bestfitgengrid = evolution(enemy, size_of_pop, generations, mutation_probability, crossover_parameter)

            if max_fitness > best_fitness:
                best_fitness = max_fitness
                best_params = {'mutation_probability': mutation_probability, 'crossover_parameter': crossover_parameter}

    return best_params, best_fitness

# Fine search
def fine_tune_search(enemy, size_of_pop, generations, best_params):
    best_fitness = -np.inf
    fine_mutation_range = np.linspace(best_params['mutation_probability'] - 0.005, best_params['mutation_probability'] + 0.005, 5)
    fine_crossover_range = np.linspace(best_params['crossover_parameter'] - 0.05, best_params['crossover_parameter'] + 0.05, 5)

    for mutation_probability in fine_mutation_range:
        for crossover_parameter in fine_crossover_range:
            print(f"Fine-tuning mutation: {mutation_probability}, crossover: {crossover_parameter}")
            fittest_individual, max_fitness, bestfitgentune = evolution(enemy, size_of_pop, generations, mutation_probability, crossover_parameter)

            if max_fitness > best_fitness:
                best_fitness = max_fitness
                best_individual = fittest_individual
                best_params = {'mutation_probability': mutation_probability, 'crossover_parameter': crossover_parameter}

    return best_params, best_fitness, best_individual

# Main function
def run():
    all_best_individuals = []
    run_results = []

    for enemy in [3]:
        print(f'\nResults for enemy {enemy}\n')

        for run in range(runs):
            print(f"Run {run+1}/{runs}")

            print("Broad parameter search has started")
            best_params, bestfitgridsearch = grid_search(enemy, size_of_pop, generations)

            print("Fine-tuning search has started")
            best_params, best_fitness, best_individual = fine_tune_search(enemy, size_of_pop, generations, best_params)

            print(f"Run {run+1} - Best parameters after fine-tuning: {best_params}, with fitness: {best_fitness}")
            run_results.append((best_params, best_fitness, best_individual))

    # Calculate mean
    param_fitness_means = {}

    for params, fitness, individual in run_results:
        param_key = (params['mutation_probability'], params['crossover_parameter'])

        if param_key in param_fitness_means:
            param_fitness_means[param_key].append(fitness)
        else:
            param_fitness_means[param_key] = [fitness]

    # Get parameters
    best_mean_params = max(param_fitness_means.items(), key=lambda x: np.mean(x[1]))[0]
    best_mean_fitness = np.mean(param_fitness_means[best_mean_params])

    # Find best individual
    for params, fitness, individual in run_results:
        if (params['mutation_probability'], params['crossover_parameter']) == best_mean_params:
            best_individual = individual
            break

    print(f"\nBest parameters based on mean fitness: Mutation {best_mean_params[0]}, Crossover {best_mean_params[1]} with mean fitness: {best_mean_fitness}")
    
    # Save the final results
    save_final_results(best_individual, best_mean_fitness, enemy, {'mutation_probability': best_mean_params[0], 'crossover_parameter': best_mean_params[1]})

run()
# Out:
# pygame 2.6.0 (SDL 2.28.4, Python 3.12.4)
# Hello from the pygame community. https://www.pygame.org/contribute.html
#
# Results for enemy 3
#
# Run 1/10
# Broad parameter search has started
# Testing mutation: 0.01, crossover: 0.3
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.01, crossover: 0.39999999999999997
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.01, crossover: 0.5
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.01, crossover: 0.6
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.01, crossover: 0.7
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0325, crossover: 0.3
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0325, crossover: 0.39999999999999997
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0325, crossover: 0.5
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0325, crossover: 0.6
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0325, crossover: 0.7
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.05500000000000001, crossover: 0.3
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.05500000000000001, crossover: 0.39999999999999997
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.05500000000000001, crossover: 0.5
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.05500000000000001, crossover: 0.6
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.05500000000000001, crossover: 0.7
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0775, crossover: 0.3
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0775, crossover: 0.39999999999999997
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0775, crossover: 0.5
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0775, crossover: 0.6
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0775, crossover: 0.7
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.1, crossover: 0.3
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.1, crossover: 0.39999999999999997
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.1, crossover: 0.5
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.1, crossover: 0.6
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.1, crossover: 0.7
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning search has started
# Fine-tuning mutation: 0.0725, crossover: 0.5499999999999999
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0725, crossover: 0.575
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0725, crossover: 0.6
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0725, crossover: 0.625
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0725, crossover: 0.65
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.075, crossover: 0.5499999999999999
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.075, crossover: 0.575
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.075, crossover: 0.6
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.075, crossover: 0.625
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.075, crossover: 0.65
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0775, crossover: 0.5499999999999999
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0775, crossover: 0.575
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0775, crossover: 0.6
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0775, crossover: 0.625
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0775, crossover: 0.65
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.08, crossover: 0.5499999999999999
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.08, crossover: 0.575
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.08, crossover: 0.6
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.08, crossover: 0.625
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.08, crossover: 0.65
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0825, crossover: 0.5499999999999999
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0825, crossover: 0.575
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0825, crossover: 0.6
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0825, crossover: 0.625
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0825, crossover: 0.65
#
# MESSAGE: Pygame initialized for simulation.
# Run 1 - Best parameters after fine-tuning: {'mutation_probability': 0.08, 'crossover_parameter': 0.6}, with fitness: 2.7833938989151354
# Run 2/10
# Broad parameter search has started
# Testing mutation: 0.01, crossover: 0.3
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.01, crossover: 0.39999999999999997
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.01, crossover: 0.5
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.01, crossover: 0.6
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.01, crossover: 0.7
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0325, crossover: 0.3
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0325, crossover: 0.39999999999999997
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0325, crossover: 0.5
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0325, crossover: 0.6
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0325, crossover: 0.7
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.05500000000000001, crossover: 0.3
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.05500000000000001, crossover: 0.39999999999999997
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.05500000000000001, crossover: 0.5
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.05500000000000001, crossover: 0.6
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.05500000000000001, crossover: 0.7
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0775, crossover: 0.3
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0775, crossover: 0.39999999999999997
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0775, crossover: 0.5
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0775, crossover: 0.6
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0775, crossover: 0.7
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.1, crossover: 0.3
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.1, crossover: 0.39999999999999997
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.1, crossover: 0.5
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.1, crossover: 0.6
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.1, crossover: 0.7
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning search has started
# Fine-tuning mutation: 0.095, crossover: 0.6499999999999999
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.095, crossover: 0.6749999999999999
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.095, crossover: 0.7
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.095, crossover: 0.725
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.095, crossover: 0.75
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0975, crossover: 0.6499999999999999
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0975, crossover: 0.6749999999999999
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0975, crossover: 0.7
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0975, crossover: 0.725
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0975, crossover: 0.75
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.1, crossover: 0.6499999999999999
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.1, crossover: 0.6749999999999999
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.1, crossover: 0.7
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.1, crossover: 0.725
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.1, crossover: 0.75
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.10250000000000001, crossover: 0.6499999999999999
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.10250000000000001, crossover: 0.6749999999999999
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.10250000000000001, crossover: 0.7
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.10250000000000001, crossover: 0.725
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.10250000000000001, crossover: 0.75
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.10500000000000001, crossover: 0.6499999999999999
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.10500000000000001, crossover: 0.6749999999999999
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.10500000000000001, crossover: 0.7
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.10500000000000001, crossover: 0.725
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.10500000000000001, crossover: 0.75
#
# MESSAGE: Pygame initialized for simulation.
# Run 2 - Best parameters after fine-tuning: {'mutation_probability': 0.10250000000000001, 'crossover_parameter': 0.6499999999999999}, with fitness: 18.421114235098877
# Run 3/10
# Broad parameter search has started
# Testing mutation: 0.01, crossover: 0.3
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.01, crossover: 0.39999999999999997
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.01, crossover: 0.5
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.01, crossover: 0.6
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.01, crossover: 0.7
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0325, crossover: 0.3
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0325, crossover: 0.39999999999999997
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0325, crossover: 0.5
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0325, crossover: 0.6
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0325, crossover: 0.7
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.05500000000000001, crossover: 0.3
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.05500000000000001, crossover: 0.39999999999999997
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.05500000000000001, crossover: 0.5
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.05500000000000001, crossover: 0.6
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.05500000000000001, crossover: 0.7
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0775, crossover: 0.3
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0775, crossover: 0.39999999999999997
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0775, crossover: 0.5
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0775, crossover: 0.6
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0775, crossover: 0.7
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.1, crossover: 0.3
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.1, crossover: 0.39999999999999997
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.1, crossover: 0.5
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.1, crossover: 0.6
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.1, crossover: 0.7
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning search has started
# Fine-tuning mutation: 0.0725, crossover: 0.6499999999999999
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0725, crossover: 0.6749999999999999
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0725, crossover: 0.7
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0725, crossover: 0.725
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0725, crossover: 0.75
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.075, crossover: 0.6499999999999999
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.075, crossover: 0.6749999999999999
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.075, crossover: 0.7
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.075, crossover: 0.725
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.075, crossover: 0.75
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0775, crossover: 0.6499999999999999
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0775, crossover: 0.6749999999999999
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0775, crossover: 0.7
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0775, crossover: 0.725
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0775, crossover: 0.75
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.08, crossover: 0.6499999999999999
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.08, crossover: 0.6749999999999999
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.08, crossover: 0.7
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.08, crossover: 0.725
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.08, crossover: 0.75
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0825, crossover: 0.6499999999999999
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0825, crossover: 0.6749999999999999
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0825, crossover: 0.7
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0825, crossover: 0.725
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0825, crossover: 0.75
#
# MESSAGE: Pygame initialized for simulation.
# Run 3 - Best parameters after fine-tuning: {'mutation_probability': 0.0725, 'crossover_parameter': 0.725}, with fitness: 27.191409973903376
# Run 4/10
# Broad parameter search has started
# Testing mutation: 0.01, crossover: 0.3
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.01, crossover: 0.39999999999999997
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.01, crossover: 0.5
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.01, crossover: 0.6
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.01, crossover: 0.7
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0325, crossover: 0.3
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0325, crossover: 0.39999999999999997
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0325, crossover: 0.5
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0325, crossover: 0.6
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0325, crossover: 0.7
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.05500000000000001, crossover: 0.3
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.05500000000000001, crossover: 0.39999999999999997
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.05500000000000001, crossover: 0.5
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.05500000000000001, crossover: 0.6
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.05500000000000001, crossover: 0.7
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0775, crossover: 0.3
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0775, crossover: 0.39999999999999997
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0775, crossover: 0.5
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0775, crossover: 0.6
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0775, crossover: 0.7
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.1, crossover: 0.3
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.1, crossover: 0.39999999999999997
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.1, crossover: 0.5
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.1, crossover: 0.6
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.1, crossover: 0.7
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning search has started
# Fine-tuning mutation: 0.0725, crossover: 0.35
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0725, crossover: 0.375
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0725, crossover: 0.39999999999999997
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0725, crossover: 0.42499999999999993
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0725, crossover: 0.44999999999999996
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.075, crossover: 0.35
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.075, crossover: 0.375
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.075, crossover: 0.39999999999999997
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.075, crossover: 0.42499999999999993
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.075, crossover: 0.44999999999999996
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0775, crossover: 0.35
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0775, crossover: 0.375
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0775, crossover: 0.39999999999999997
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0775, crossover: 0.42499999999999993
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0775, crossover: 0.44999999999999996
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.08, crossover: 0.35
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.08, crossover: 0.375
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.08, crossover: 0.39999999999999997
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.08, crossover: 0.42499999999999993
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.08, crossover: 0.44999999999999996
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0825, crossover: 0.35
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0825, crossover: 0.375
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0825, crossover: 0.39999999999999997
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0825, crossover: 0.42499999999999993
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0825, crossover: 0.44999999999999996
#
# MESSAGE: Pygame initialized for simulation.
# Run 4 - Best parameters after fine-tuning: {'mutation_probability': 0.0775, 'crossover_parameter': 0.35}, with fitness: 36.26877351051686
# Run 5/10
# Broad parameter search has started
# Testing mutation: 0.01, crossover: 0.3
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.01, crossover: 0.39999999999999997
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.01, crossover: 0.5
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.01, crossover: 0.6
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.01, crossover: 0.7
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0325, crossover: 0.3
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0325, crossover: 0.39999999999999997
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0325, crossover: 0.5
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0325, crossover: 0.6
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0325, crossover: 0.7
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.05500000000000001, crossover: 0.3
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.05500000000000001, crossover: 0.39999999999999997
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.05500000000000001, crossover: 0.5
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.05500000000000001, crossover: 0.6
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.05500000000000001, crossover: 0.7
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0775, crossover: 0.3
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0775, crossover: 0.39999999999999997
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0775, crossover: 0.5
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0775, crossover: 0.6
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0775, crossover: 0.7
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.1, crossover: 0.3
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.1, crossover: 0.39999999999999997
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.1, crossover: 0.5
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.1, crossover: 0.6
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.1, crossover: 0.7
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning search has started
# Fine-tuning mutation: 0.095, crossover: 0.5499999999999999
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.095, crossover: 0.575
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.095, crossover: 0.6
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.095, crossover: 0.625
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.095, crossover: 0.65
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0975, crossover: 0.5499999999999999
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0975, crossover: 0.575
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0975, crossover: 0.6
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0975, crossover: 0.625
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0975, crossover: 0.65
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.1, crossover: 0.5499999999999999
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.1, crossover: 0.575
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.1, crossover: 0.6
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.1, crossover: 0.625
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.1, crossover: 0.65
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.10250000000000001, crossover: 0.5499999999999999
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.10250000000000001, crossover: 0.575
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.10250000000000001, crossover: 0.6
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.10250000000000001, crossover: 0.625
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.10250000000000001, crossover: 0.65
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.10500000000000001, crossover: 0.5499999999999999
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.10500000000000001, crossover: 0.575
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.10500000000000001, crossover: 0.6
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.10500000000000001, crossover: 0.625
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.10500000000000001, crossover: 0.65
#
# MESSAGE: Pygame initialized for simulation.
# Run 5 - Best parameters after fine-tuning: {'mutation_probability': 0.10250000000000001, 'crossover_parameter': 0.5499999999999999}, with fitness: 48.79342407327507
# Run 6/10
# Broad parameter search has started
# Testing mutation: 0.01, crossover: 0.3
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.01, crossover: 0.39999999999999997
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.01, crossover: 0.5
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.01, crossover: 0.6
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.01, crossover: 0.7
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0325, crossover: 0.3
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0325, crossover: 0.39999999999999997
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0325, crossover: 0.5
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0325, crossover: 0.6
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0325, crossover: 0.7
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.05500000000000001, crossover: 0.3
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.05500000000000001, crossover: 0.39999999999999997
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.05500000000000001, crossover: 0.5
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.05500000000000001, crossover: 0.6
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.05500000000000001, crossover: 0.7
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0775, crossover: 0.3
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0775, crossover: 0.39999999999999997
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0775, crossover: 0.5
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0775, crossover: 0.6
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0775, crossover: 0.7
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.1, crossover: 0.3
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.1, crossover: 0.39999999999999997
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.1, crossover: 0.5
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.1, crossover: 0.6
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.1, crossover: 0.7
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning search has started
# Fine-tuning mutation: 0.0275, crossover: 0.45
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0275, crossover: 0.47500000000000003
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0275, crossover: 0.5
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0275, crossover: 0.525
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0275, crossover: 0.55
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.03, crossover: 0.45
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.03, crossover: 0.47500000000000003
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.03, crossover: 0.5
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.03, crossover: 0.525
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.03, crossover: 0.55
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0325, crossover: 0.45
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0325, crossover: 0.47500000000000003
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0325, crossover: 0.5
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0325, crossover: 0.525
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0325, crossover: 0.55
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.034999999999999996, crossover: 0.45
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.034999999999999996, crossover: 0.47500000000000003
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.034999999999999996, crossover: 0.5
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.034999999999999996, crossover: 0.525
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.034999999999999996, crossover: 0.55
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0375, crossover: 0.45
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0375, crossover: 0.47500000000000003
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0375, crossover: 0.5
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0375, crossover: 0.525
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0375, crossover: 0.55
#
# MESSAGE: Pygame initialized for simulation.
# Run 6 - Best parameters after fine-tuning: {'mutation_probability': 0.0275, 'crossover_parameter': 0.55}, with fitness: 25.39140997390337
# Run 7/10
# Broad parameter search has started
# Testing mutation: 0.01, crossover: 0.3
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.01, crossover: 0.39999999999999997
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.01, crossover: 0.5
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.01, crossover: 0.6
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.01, crossover: 0.7
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0325, crossover: 0.3
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0325, crossover: 0.39999999999999997
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0325, crossover: 0.5
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0325, crossover: 0.6
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0325, crossover: 0.7
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.05500000000000001, crossover: 0.3
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.05500000000000001, crossover: 0.39999999999999997
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.05500000000000001, crossover: 0.5
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.05500000000000001, crossover: 0.6
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.05500000000000001, crossover: 0.7
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0775, crossover: 0.3
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0775, crossover: 0.39999999999999997
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0775, crossover: 0.5
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0775, crossover: 0.6
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0775, crossover: 0.7
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.1, crossover: 0.3
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.1, crossover: 0.39999999999999997
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.1, crossover: 0.5
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.1, crossover: 0.6
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.1, crossover: 0.7
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning search has started
# Fine-tuning mutation: 0.05000000000000001, crossover: 0.45
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.05000000000000001, crossover: 0.47500000000000003
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.05000000000000001, crossover: 0.5
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.05000000000000001, crossover: 0.525
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.05000000000000001, crossover: 0.55
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.052500000000000005, crossover: 0.45
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.052500000000000005, crossover: 0.47500000000000003
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.052500000000000005, crossover: 0.5
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.052500000000000005, crossover: 0.525
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.052500000000000005, crossover: 0.55
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.05500000000000001, crossover: 0.45
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.05500000000000001, crossover: 0.47500000000000003
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.05500000000000001, crossover: 0.5
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.05500000000000001, crossover: 0.525
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.05500000000000001, crossover: 0.55
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.05750000000000001, crossover: 0.45
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.05750000000000001, crossover: 0.47500000000000003
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.05750000000000001, crossover: 0.5
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.05750000000000001, crossover: 0.525
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.05750000000000001, crossover: 0.55
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.060000000000000005, crossover: 0.45
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.060000000000000005, crossover: 0.47500000000000003
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.060000000000000005, crossover: 0.5
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.060000000000000005, crossover: 0.525
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.060000000000000005, crossover: 0.55
#
# MESSAGE: Pygame initialized for simulation.
# Run 7 - Best parameters after fine-tuning: {'mutation_probability': 0.05750000000000001, 'crossover_parameter': 0.525}, with fitness: 11.075316609105794
# Run 8/10
# Broad parameter search has started
# Testing mutation: 0.01, crossover: 0.3
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.01, crossover: 0.39999999999999997
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.01, crossover: 0.5
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.01, crossover: 0.6
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.01, crossover: 0.7
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0325, crossover: 0.3
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0325, crossover: 0.39999999999999997
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0325, crossover: 0.5
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0325, crossover: 0.6
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0325, crossover: 0.7
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.05500000000000001, crossover: 0.3
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.05500000000000001, crossover: 0.39999999999999997
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.05500000000000001, crossover: 0.5
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.05500000000000001, crossover: 0.6
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.05500000000000001, crossover: 0.7
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0775, crossover: 0.3
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0775, crossover: 0.39999999999999997
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0775, crossover: 0.5
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0775, crossover: 0.6
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0775, crossover: 0.7
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.1, crossover: 0.3
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.1, crossover: 0.39999999999999997
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.1, crossover: 0.5
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.1, crossover: 0.6
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.1, crossover: 0.7
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning search has started
# Fine-tuning mutation: 0.005, crossover: 0.6499999999999999
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.005, crossover: 0.6749999999999999
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.005, crossover: 0.7
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.005, crossover: 0.725
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.005, crossover: 0.75
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0075, crossover: 0.6499999999999999
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0075, crossover: 0.6749999999999999
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0075, crossover: 0.7
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0075, crossover: 0.725
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0075, crossover: 0.75
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.009999999999999998, crossover: 0.6499999999999999
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.009999999999999998, crossover: 0.6749999999999999
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.009999999999999998, crossover: 0.7
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.009999999999999998, crossover: 0.725
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.009999999999999998, crossover: 0.75
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.012499999999999999, crossover: 0.6499999999999999
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.012499999999999999, crossover: 0.6749999999999999
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.012499999999999999, crossover: 0.7
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.012499999999999999, crossover: 0.725
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.012499999999999999, crossover: 0.75
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.015, crossover: 0.6499999999999999
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.015, crossover: 0.6749999999999999
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.015, crossover: 0.7
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.015, crossover: 0.725
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.015, crossover: 0.75
#
# MESSAGE: Pygame initialized for simulation.
# Run 8 - Best parameters after fine-tuning: {'mutation_probability': 0.005, 'crossover_parameter': 0.75}, with fitness: 27.191409973903376
# Run 9/10
# Broad parameter search has started
# Testing mutation: 0.01, crossover: 0.3
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.01, crossover: 0.39999999999999997
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.01, crossover: 0.5
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.01, crossover: 0.6
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.01, crossover: 0.7
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0325, crossover: 0.3
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0325, crossover: 0.39999999999999997
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0325, crossover: 0.5
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0325, crossover: 0.6
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0325, crossover: 0.7
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.05500000000000001, crossover: 0.3
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.05500000000000001, crossover: 0.39999999999999997
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.05500000000000001, crossover: 0.5
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.05500000000000001, crossover: 0.6
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.05500000000000001, crossover: 0.7
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0775, crossover: 0.3
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0775, crossover: 0.39999999999999997
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0775, crossover: 0.5
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0775, crossover: 0.6
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0775, crossover: 0.7
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.1, crossover: 0.3
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.1, crossover: 0.39999999999999997
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.1, crossover: 0.5
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.1, crossover: 0.6
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.1, crossover: 0.7
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning search has started
# Fine-tuning mutation: 0.095, crossover: 0.6499999999999999
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.095, crossover: 0.6749999999999999
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.095, crossover: 0.7
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.095, crossover: 0.725
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.095, crossover: 0.75
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0975, crossover: 0.6499999999999999
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0975, crossover: 0.6749999999999999
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0975, crossover: 0.7
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0975, crossover: 0.725
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0975, crossover: 0.75
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.1, crossover: 0.6499999999999999
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.1, crossover: 0.6749999999999999
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.1, crossover: 0.7
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.1, crossover: 0.725
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.1, crossover: 0.75
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.10250000000000001, crossover: 0.6499999999999999
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.10250000000000001, crossover: 0.6749999999999999
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.10250000000000001, crossover: 0.7
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.10250000000000001, crossover: 0.725
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.10250000000000001, crossover: 0.75
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.10500000000000001, crossover: 0.6499999999999999
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.10500000000000001, crossover: 0.6749999999999999
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.10500000000000001, crossover: 0.7
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.10500000000000001, crossover: 0.725
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.10500000000000001, crossover: 0.75
#
# MESSAGE: Pygame initialized for simulation.
# Run 9 - Best parameters after fine-tuning: {'mutation_probability': 0.0975, 'crossover_parameter': 0.6749999999999999}, with fitness: 72.32926227199752
# Run 10/10
# Broad parameter search has started
# Testing mutation: 0.01, crossover: 0.3
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.01, crossover: 0.39999999999999997
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.01, crossover: 0.5
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.01, crossover: 0.6
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.01, crossover: 0.7
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0325, crossover: 0.3
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0325, crossover: 0.39999999999999997
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0325, crossover: 0.5
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0325, crossover: 0.6
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0325, crossover: 0.7
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.05500000000000001, crossover: 0.3
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.05500000000000001, crossover: 0.39999999999999997
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.05500000000000001, crossover: 0.5
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.05500000000000001, crossover: 0.6
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.05500000000000001, crossover: 0.7
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0775, crossover: 0.3
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0775, crossover: 0.39999999999999997
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0775, crossover: 0.5
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0775, crossover: 0.6
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.0775, crossover: 0.7
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.1, crossover: 0.3
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.1, crossover: 0.39999999999999997
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.1, crossover: 0.5
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.1, crossover: 0.6
#
# MESSAGE: Pygame initialized for simulation.
# Testing mutation: 0.1, crossover: 0.7
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning search has started
# Fine-tuning mutation: 0.0275, crossover: 0.5499999999999999
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0275, crossover: 0.575
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0275, crossover: 0.6
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0275, crossover: 0.625
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0275, crossover: 0.65
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.03, crossover: 0.5499999999999999
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.03, crossover: 0.575
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.03, crossover: 0.6
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.03, crossover: 0.625
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.03, crossover: 0.65
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0325, crossover: 0.5499999999999999
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0325, crossover: 0.575
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0325, crossover: 0.6
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0325, crossover: 0.625
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0325, crossover: 0.65
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.034999999999999996, crossover: 0.5499999999999999
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.034999999999999996, crossover: 0.575
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.034999999999999996, crossover: 0.6
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.034999999999999996, crossover: 0.625
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.034999999999999996, crossover: 0.65
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0375, crossover: 0.5499999999999999
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0375, crossover: 0.575
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0375, crossover: 0.6
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0375, crossover: 0.625
#
# MESSAGE: Pygame initialized for simulation.
# Fine-tuning mutation: 0.0375, crossover: 0.65
#
# MESSAGE: Pygame initialized for simulation.
# Run 10 - Best parameters after fine-tuning: {'mutation_probability': 0.03, 'crossover_parameter': 0.575}, with fitness: 50.593424073275074
#
# Best parameters based on mean fitness: Mutation 0.0975, Crossover 0.6749999999999999 with mean fitness: 72.32926227199752
